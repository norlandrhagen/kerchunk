# %%
import kerchunk
import fsspec
import xarray as xr
import rioxarray
import ujson
import s3fs
import zarr 

import imagecodecs.numcodecs
imagecodecs.numcodecs.register_codecs()

from kerchunk.tiff import tiff_to_zarr
ex_path = 'https://github.com/fsspec/kerchunk/blob/main/kerchunk/tests/lcmap_tiny_cog_2019.tif?raw=true'
ex_path = 's3://carbonplan-scratch/tiff_ex.tif'

# ex_ds = xr.open_dataset(ex_path,engine='rasterio')

# %%
# zt = tiff_to_zarr(ex_path, remote_options={'protocol':'s3'}, target=None, target_options=None)
# with open('coords.json', "wb") as f:
#     f.write(ujson.dumps(zt).encode())

# %%
gcm = fsspec.get_mapper("reference://", fo='coords.json')

# %%
z = zarr.open(gcm)

# %%
z['data'].info
# Out:
# Name               : /data
# Type               : zarr.core.Array
# Data type          : float32
# Shape              : (2048, 2048)
# Chunk shape        : (1, 2048)
# Order              : C
# Read-only          : False
# Compressor         : None
# Store type         : zarr.storage.FSStore
# No. bytes          : 16777216 (16.0M)
# No. bytes stored   : 16778206 (16.0M)
# Storage ratio      : 1.0
# Chunks initialized : 2048/2048

# %%
ex_ds = xr.open_dataset(
    gcm, engine="zarr", backend_kwargs={"consolidated": False}

)

# %%
ex_ds
# Out:
# <xarray.Dataset>
# Dimensions:  (Y: 2048, X: 2048, south_north: 250, west_east: 320)
# Coordinates:
#     lat      (south_north, west_east) float32 ...
#     lon      (south_north, west_east) float32 ...
# Dimensions without coordinates: Y, X, south_north, west_east
# Data variables:
#     data     (Y, X) float32 ...

# %%
netcdf_ref = fsspec.get_mapper("reference://", fo='test.json')

# %%
ncds = xr.open_dataset(
    netcdf_ref, engine="zarr", backend_kwargs={"consolidated": False}

)

# %%
ncds
